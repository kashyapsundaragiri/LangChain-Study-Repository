# %% [markdown]
# ## Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
# Export all the variables inside .env
import os
from dotenv import load_dotenv
load_dotenv()
os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
# Langsmith tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000001970F0A3040> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001970F9FB6D0> root_client=<openai.OpenAI object at 0x000001970F0A25F0> root_async_client=<openai.AsyncOpenAI object at 0x000001970F0A39A0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %%
# Input and get response from llm
result=llm.invoke("What is Generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a class of artificial intelligence systems designed to generate new content, such as text, images, music, or even video, in a way that mimics human creativity. Unlike discriminative models, which focus on identifying patterns or making predictions based on input data, generative models aim to create outputs that are similar to a given set of examples.\n\nKey technologies and approaches in generative AI include:\n\n1. **Generative Adversarial Networks (GANs):** These consist of two neural networks, a generator and a discriminator, pitted against each other. The generator creates samples, and the discriminator evaluates them. This iterative process continues until the generator produces outputs that are indistinguishable from real data.\n\n2. **Variational Autoencoders (VAEs):** VAEs are probabilistic models that learn the underlying structure of data, allowing them to generate new, similar samples. They encode input data into a latent space and then decode it back into the original domain.\n\n3. **Transformer Models:** These are highly influential in generating sequences of data, particularly text. Models like GPT-3 and GPT-4, based on transformers, are capable of understanding and generating human-like text across various contexts.\n\n4. **Diffusion Models:** These are a class of generative models that gradually transform random noise into meaningful data, often used in tasks like image synthesis.\n\nGenerative AI applications are vast and growing, impacting fields like content creation, entertainment, design, programming, and even drug discovery by creating novel solutions or ideas that are difficult to derive manually.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 315, 'prompt_tokens': 13, 'total_tokens': 328, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f0c49cb276', 'id': 'chatcmpl-DoQ8PbhjwLiFI6DUWaQY8OGxWEe2V', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ea676-51b3-7943-b054-78c9f828525a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 315, 'total_tokens': 328, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# Chat Prompt Template
from langchain_core.prompts import ChatPromptTemplate
prompt= ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert AI Engineer. Provide me answers based on questions"),
        ("user", "{input}")


    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain= prompt|llm  # Chain means to combine multiple things

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a development framework and toolset designed to enhance the capabilities and efficiency of applications built with large language models (LLMs). It provides developers with a suite of tools to manage, monitor, and optimize interactions with LLMs, aiming to create more reliable and scalable AI-driven applications. Langsmith includes features for testing, debugging, and analyzing the performance of language models, making it easier for developers to fine-tune model responses and ensure alignment with application goals. The framework is part of a broader ecosystem around language models, targeting improved integration, efficiency, and user experience in AI development projects.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 120, 'prompt_tokens': 32, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f3e2534334', 'id': 'chatcmpl-DoQNTCzEXS9GeFxDPsKVIqzhkaMvM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ea684-93b0-71a1-8415-328890fc9d79-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 32, 'output_tokens': 120, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
# Str Output Parser

from langchain_core.output_parsers import StrOutputParser
output_parser= StrOutputParser()
chain= prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a comprehensive developer toolkit provided by Langchain, designed to facilitate various aspects of AI model development and deployment. It offers features that streamline the creation and management of language models, including capabilities for experimentation, evaluation, and debugging of LLM (Large Language Model) applications.
#
# Key features of Langsmith include:
#
# 1. **Experimentation Tools**: Langsmith provides utilities that allow developers to experiment with different model configurations and prompt strategies, making it easier to optimize model performance.
#
# 2. **Evaluation and Debugging**: It allows developers to evaluate the outputs of LLMs rigorously and to debug their applications effectively, ensuring more reliable and accurate language model deployments.
#
# 3. **Monitoring and Logging**: The toolkit includes features for monitoring the performance of models in real time, as well as logging tools for tracking the behavior and outputs of LLMs across different scenarios.
#
# 4. **Integration with Langchain**: Langsmith is designed to seamlessly integrate with the Langchain framework, enhancing its capabilities for building robust, scalable, and customizable AI-powered applications.
#
# Overall, Langsmith is aimed at improving the workflow of developers working with language models by providing a structured environment to develop, test, and refine their AI models and applications.
